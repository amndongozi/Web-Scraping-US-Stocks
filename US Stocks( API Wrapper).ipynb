# %%
## Installing the API Wrapper
# Instead of downloading DOW data from the Yahoo Finance Website, we can install an API wrapper (yfinance) in Anaconda which is more scalable for data access
# This is done in Anaconda prompt: pip install yfinance

# %%
import pandas as pd
import yfinance as yf

# %%
yf.download("^DJI", multi_level_index=False) # The multi level index removes the unnecessary ^DJI duplicated row
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Close          High           Low          Open      Volume
# Date
# 1992-01-02   3172.399902   3172.629883   3139.310059   3152.100098    23550000
# 1992-01-03   3201.500000   3210.639893   3165.919922   3172.399902    23620000
# 1992-01-06   3200.100098   3213.330078   3191.860107   3201.500000    27280000
# 1992-01-07   3204.800049   3210.199951   3184.479980   3200.100098    25510000
# 1992-01-08   3203.899902   3229.199951   3185.820068   3204.800049    29040000
# ...                  ...           ...           ...           ...         ...
# 2024-12-19  42342.238281  42787.851562  42334.128906  42464.128906   560200000
# 2024-12-20  42840.261719  43216.031250  42146.328125  42296.261719  1121300000
# 2024-12-23  42906.949219  42957.789062  42516.871094  42800.488281   449390000
# 2024-12-24  43297.031250  43297.648438  42871.761719  42916.480469   230410000
# ...

# %%
dowdata= yf.download("^DJI", start = '2007-01-01', end = '2020-03-31', multi_level_index=False)
dowdata
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Close          High           Low          Open     Volume
# Date
# 2007-01-03  12474.519531  12580.349609  12404.820312  12459.540039  327200000
# 2007-01-04  12480.690430  12510.410156  12403.860352  12473.160156  259060000
# 2007-01-05  12398.009766  12480.129883  12365.410156  12480.049805  235220000
# 2007-01-08  12423.490234  12445.919922  12337.370117  12392.009766  223500000
# 2007-01-09  12416.599609  12466.429688  12369.169922  12424.769531  225190000
# ...                  ...           ...           ...           ...        ...
# 2020-03-24  20704.910156  20737.699219  19649.250000  19722.189453  799340000
# 2020-03-25  21200.550781  22019.929688  20538.339844  21050.339844  796320000
# 2020-03-26  22552.169922  22595.060547  21427.099609  21468.380859  705180000
# 2020-03-27  21636.779297  22327.570312  21469.269531  21898.470703  588830000
# ...

# %%
dowdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3333 entries, 2007-01-03 to 2020-03-30
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   3333 non-null   float64
#  1   High    3333 non-null   float64
#  2   Low     3333 non-null   float64
#  3   Open    3333 non-null   float64
#  4   Volume  3333 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 156.2 KB

# %%
dowdata.to_csv("dowdata.csv")

# %%
ticker = pd.read_csv("ticker_list")
# print(type(ticker))
ticker = ticker['Ticker'].tolist()  # Convert the ticker dataframe to a list
ticker
# print(type(ticker))
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AMZN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DIS',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'NVDA',
#  'PG',
#  'CRM',
#  'SHW',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WMT']

# %%
# This comibnes the prices and the 30 ticker list of companies
prices = yf.download(ticker, start = '2007-01-01', end = '2020-03-31')
prices
# Out:
# [*********************100%***********************]  30 of 30 completed
# Price           Close                                                \
# Ticker           AAPL        AMGN       AMZN        AXP          BA
# Date
# 2007-01-03   2.524616   48.486603   1.935000  45.753906   64.405716
# 2007-01-04   2.580653   50.563587   1.945000  45.420380   64.665749
# 2007-01-05   2.562274   50.684090   1.918500  44.821541   64.391258
# 2007-01-08   2.574929   50.280033   1.875000  45.246033   64.239571
# 2007-01-09   2.788826   50.521057   1.889000  44.957977   63.560650
# ...               ...         ...        ...        ...         ...
# 2020-03-24  59.978466  176.322861  97.004997  78.737213  127.680000
# 2020-03-25  59.648067  168.305817  94.292000  84.470390  158.729996
# 2020-03-26  62.786919  172.967926  97.774498  87.393150  180.550003
# 2020-03-27  60.187401  172.776184  95.004997  83.121414  162.000000
# 2020-03-30  61.905029  181.673370  98.197502  84.564064  152.279999
#
# ...

# %%
prices
# Out:
# Price           Close                                                \
# Ticker           AAPL        AMGN       AMZN        AXP          BA
# Date
# 2007-01-03   2.524616   48.486603   1.935000  45.753906   64.405716
# 2007-01-04   2.580653   50.563587   1.945000  45.420380   64.665749
# 2007-01-05   2.562274   50.684090   1.918500  44.821541   64.391258
# 2007-01-08   2.574929   50.280033   1.875000  45.246033   64.239571
# 2007-01-09   2.788826   50.521057   1.889000  44.957977   63.560650
# ...               ...         ...        ...        ...         ...
# 2020-03-24  59.978466  176.322861  97.004997  78.737213  127.680000
# 2020-03-25  59.648067  168.305817  94.292000  84.470390  158.729996
# 2020-03-26  62.786919  172.967926  97.774498  87.393150  180.550003
# 2020-03-27  60.187401  172.776184  95.004997  83.121414  162.000000
# 2020-03-30  61.905029  181.673370  98.197502  84.564064  152.279999
#
# ...

# %%
# Getting only the Closing prices for the end of the day
prices = prices.loc[:, "Close"].copy()

# %%
prices
# Out:
# Ticker           AAPL        AMGN       AMZN        AXP          BA  \
# Date
# 2007-01-03   2.524616   48.486603   1.935000  45.753906   64.405716
# 2007-01-04   2.580653   50.563587   1.945000  45.420380   64.665749
# 2007-01-05   2.562274   50.684090   1.918500  44.821541   64.391258
# 2007-01-08   2.574929   50.280033   1.875000  45.246033   64.239571
# 2007-01-09   2.788826   50.521057   1.889000  44.957977   63.560650
# ...               ...         ...        ...        ...         ...
# 2020-03-24  59.978466  176.322861  97.004997  78.737213  127.680000
# 2020-03-25  59.648067  168.305817  94.292000  84.470390  158.729996
# 2020-03-26  62.786919  172.967926  97.774498  87.393150  180.550003
# 2020-03-27  60.187401  172.776184  95.004997  83.121414  162.000000
# 2020-03-30  61.905029  181.673370  98.197502  84.564064  152.279999
#
# Ticker             CAT         CRM       CSCO        CVX         DIS  ...  \
# ...

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3333 entries, 2007-01-03 to 2020-03-30
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3333 non-null   float64
#  1   AMGN    3333 non-null   float64
#  2   AMZN    3333 non-null   float64
#  3   AXP     3333 non-null   float64
#  4   BA      3333 non-null   float64
#  5   CAT     3333 non-null   float64
#  6   CRM     3333 non-null   float64
#  7   CSCO    3333 non-null   float64
#  8   CVX     3333 non-null   float64
#  9   DIS     3333 non-null   float64
#  10  GS      3333 non-null   float64
#  11  HD      3333 non-null   float64
#  12  HON     3333 non-null   float64
#  13  IBM     3333 non-null   float64
#  14  JNJ     3333 non-null   float64
#  15  JPM     3333 non-null   float64
#  16  KO      3333 non-null   float64
#  17  MCD     3333 non-null   float64
#  18  MMM     3333 non-null   float64
#  19  MRK     3333 non-null   float64
# ...

# %%
prices.to_csv("stock_prices.csv")
